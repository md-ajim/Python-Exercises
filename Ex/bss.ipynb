# %%
import datetime 

currentDt = datetime.datetime.now()


print(currentDt)

# %%
import cowsay
cowsay.daemon('Code With Finesse')
# Out:
#   _________________
# | Code With Finesse |
#   =================
#                          \
#                           \
#                            \
#                             \
#                              /- _  `-/  '
#                             (/\/ \ \   /\
#                             / /   | `    \
#                             O O   ) /    |
#                             `-^--'`<     '
#                            (_.)  _  )   /
#                             `.___/`    /
#                               `-----' /
#                  <----.     __ / __   \
#                  <----|====O)))==) \) /====
#                  <----'    `--' `.__,' \
#                               |        |
#                                \       /
#                          ______( (_  / \______
#                        ,'  ,-----'   |        \
#                        `--{__________)        \/

# %%
import cowsay
cowsay.cow('Hello World')
# Out:
#   ___________
# | Hello World |
#   ===========
#            \
#             \
#               ^__^
#               (oo)\_______
#               (__)\       )\/\
#                   ||----w |
#                   ||     ||

# %%
print(cowsay.get_output_string('trex', 'Hello (extinct) World'))
# Out:
#   _____________________
# | Hello (extinct) World |
#   =====================
#                             \
#                              \
#                               \
#                                \
#                                   .-=-==--==--.
#                             ..-=="  ,'o`)      `.
#                           ,'         `"'         \
#                          :  (                     `.__...._
#                          |                  )    /         `-=-.
#                          :       ,vv.-._   /    /               `---==-._
#                           \/\/\/VV ^ d88`;'    /                         `.
#                               ``  ^/d88P!'    /             ,              `._
#                                  ^/    !'   ,.      ,      /                  "-,,__,,--'""""-.
#                                 ^/    !'  ,'  \ . .(      (         _           )  ) ) ) ))_,-.\
#                                ^(__ ,!',"'   ;:+.:%:a.     \:.. . ,'          )  )  ) ) ,"'    '
#                                ',,,'','     /o:::":%:%a.    \:.:.:         .    )  ) _,'
#                                 """'       ;':::'' `+%%%a._  \%:%|         ;.). _,-""
#                                        ,-='_.-'      ``:%::)  )%:|        /:._,"
#                                       (/(/"           ," ,'_,'%%%:       (_,'
#                                                      (  (//(`.___;        \
#                                                       \     \    `         `
#                                                        `.    `.   `.        :
#                                                          \. . .\    : . . . :
#                                                           \. . .:    `.. . .:
#                                                            `..:.:\     \:...\
#                                                             ;:.:.;      ::...:
#                                                             ):%::       :::::;
#                                                         __,::%:(        :::::
#                                                      ,;:%%%%%%%:        ;:%::
#                                                        ;,--""-.`\  ,=--':%:%:\
#                                                       /"       "| /-".:%%%%%%%\
#                                                                       ;,-"'`)%%)
#                                                                      /"      "|

# %%
import squareup

# %%
try:
  print("I will try to print this line of code")
except:
  print("I will print this line of code if an error is encountered")

# %%
try:
  
  print(x)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
class First(object):
    def __init__(self):
        super(First, self).__init__()
        print("first")

class Second(object):
    def __init__(self):
        super(Second, self).__init__()
        print("second")

class Third(First, Second):
    def __init__(self):
        super(Third, self).__init__()
        print("third")

# %%
try:
  print(x)
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable x is not defined

# %%
try:
  print("Hello")
#   print(x)
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
try:
  f = open("demofile.txt")
  try:
    f.write("Lorum Ipsum")
  except:
    print("Something went wrong when writing to the file")
  finally:
    f.close()
except:
  print("Something went wrong when opening the file")
# Out:
# Something went wrong when opening the file

# %%
x = -1

if x < 0:
  raise Exception("Sorry, no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# E:\TIMP/ipykernel_10260/3386925827.py in <module>
#       2
#       3 if x < 0:
# ----> 4   raise Exception("Sorry, no numbers below zero")
#
# Exception: Sorry, no numbers below zero

# %%
x = "hello"

if not type(x) is int:
  raise TypeError("Only integers are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# E:\TIMP/ipykernel_10260/2407302476.py in <module>
#       2
#       3 if not type(x) is int:
# ----> 4   raise TypeError("Only integers are allowed")
#
# TypeError: Only integers are allowed
